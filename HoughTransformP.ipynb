# %% [markdown]
# <a href="https://colab.research.google.com/github/mharis0014/cv/blob/master/HoughTransformP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
img = cv2.imread('soduko.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
from google.colab.patches import cv2_imshow
edges = cv2.Canny(gray,50,150,apertureSize = 3)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=1200x1200 at 0x7F414C7E3978>

# %%
lines = cv2.HoughLinesP(edges,1,np.pi/180,100,minLineLength=100,maxLineGap=10)
for line in lines:
    x1,y1,x2,y2 = line[0]
    cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)

# %%
cv2_imshow(img)
k = cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7F414C7E34A8>
